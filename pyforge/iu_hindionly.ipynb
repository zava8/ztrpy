# %%
import fontforge
import os
import shutil
# import importlib
from iudhin import iudhin
scripts = (
    # "ing",
    "hindi",
    "bangla","guzrati","gurmukhi","oriya",
    "korean",
    "telugu","tamil","kannada","malayalam","sinhala"
    # ,"eng","binaryv","binaryh","hex",
    # "notosans"
)
# ff_dict={}
qvjtx2aDHTt = {"A":"q","H":"j","T":"t","D":"v","t":"x"}

# %%
for k in iudhin:
    print(f"{k}: ",end="")
    for x in iudhin[k]:
        print(hex(x),end=", ")
    print()
# Out:
# e: 0x904, 0x90d, 0x90e, 0x90f, 0x910, 0x93a, 0x945, 0x946, 0x947, 0x948, 0x955,
# a: 0x903, 0x905, 0x973, 0x976,
# A: 0x906, 0x911, 0x93e, 0x972, 0x974,
# i: 0x907, 0x908, 0x93b, 0x940,
# u: 0x909, 0x90a, 0x941, 0x942, 0x956, 0x957, 0x977,
# r: 0x90b, 0x930, 0x931, 0x943, 0x944, 0x960, 0x95d,
# l: 0x90c, 0x932, 0x933, 0x934, 0x961, 0x962, 0x963,
# o: 0x912, 0x913, 0x914, 0x949, 0x94a, 0x94b, 0x94c, 0x94f, 0x950, 0x975,
# k: 0x915, 0x958,
# K: 0x916, 0x959,
# g: 0x917, 0x95a, 0x97b,
# G: 0x918,
# c: 0x91a,
# C: 0x91b,
# z: 0x91c, 0x95b, 0x979, 0x97c,
# Z: 0x91d,
# n: 0x91e, 0x923, 0x928, 0x929,
# N: 0x919,
# t: 0x91f, 0x920,
# T: 0x924, 0x925,
# d: 0x921, 0x922, 0x95c, 0x978, 0x97e,
# D: 0x926, 0x927,
# p: 0x92a,
# f: 0x92b, 0x95e,
# b: 0x92c, 0x97f,
# B: 0x92d,
# m: 0x92e,
# y: 0x92f, 0x95f, 0x97a,
# w: 0x935,
# S: 0x936,
# s: 0x937, 0x938,
# H: 0x939,
# 0: 0x966,
# 1: 0x967,
# 2: 0x968,
# 3: 0x969,
# 4: 0x96a,
# 5: 0x96b,
# 6: 0x96c,
# 7: 0x96d,
# 8: 0x96e,
# 9: 0x96f,

# %%
for k,v in iudhin.items():
    print(k[0])
    for val in v:
        print(val)
# Out:
# e
# 2308
# 2317
# 2318
# 2319
# 2320
# 2362
# 2373
# 2374
# 2375
# 2376
# 2389
# a
# 2307
# 2309
# 2419
# 2422
# A
# 2310
# 2321
# 2366
# 2418
# 2420
# i
# 2311
# 2312
# 2363
# 2368
# u
# 2313
# 2314
# 2369
# 2370
# 2390
# 2391
# 2423
# r
# 2315
# 2352
# 2353
# 2371
# 2372
# 2400
# 2397
# l
# 2316
# 2354
# 2355
# 2356
# 2401
# 2402
# 2403
# o
# 2322
# 2323
# 2324
# 2377
# 2378
# 2379
# 2380
# 2383
# 2384
# 2421
# k
# 2325
# 2392
# K
# 2326
# 2393
# g
# 2327
# 2394
# 2427
# G
# 2328
# c
# 2330
# C
# 2331
# z
# 2332
# 2395
# 2425
# 2428
# Z
# 2333
# n
# 2334
# 2339
# 2344
# 2345
# N
# 2329
# t
# 2335
# 2336
# T
# 2340
# 2341
# d
# 2337
# 2338
# 2396
# 2424
# 2430
# D
# 2342
# 2343
# p
# 2346
# f
# 2347
# 2398
# b
# 2348
# 2431
# B
# 2349
# m
# 2350
# y
# 2351
# 2399
# 2426
# w
# 2357
# S
# 2358
# s
# 2359
# 2360
# H
# 2361
# 0
# 2406
# 1
# 2407
# 2
# 2408
# 3
# 2409
# 4
# 2410
# 5
# 2411
# 6
# 2412
# 7
# 2413
# 8
# 2414
# 9
# 2415

# %%
# copy reference from ascii to unicodehindi
scripts = (
    # "ing",
    "hindi",
    # "bangla","guzrati","gurmukhi","oriya",
    # "korean",
    # "telugu","tamil","kannada","malayalam","sinhala"
    # ,"eng","binaryv","binaryh","hex",
    # "notosans"
)
for x in scripts:
    x115 = fontforge.open(f"/home/viml/mg/font/sfd/5/115/{x}115.sfd")
    for k,v in iudhin.items():
        x115.selection.select(k[0])
        x115.copyReference()
        for val in v:
            x115.selection.select(val)
            x115.paste()
    x115.save()
    x115.close()

# %%
for x in range(1, 9):
    xmultiplyx80 = x * 0x80
    print(hex(xmultiplyx80))

# %%
# copy unicode hindi to other unicode indik
scripts = (
    "ing",
    "hindi",
    "bangla","guzrati","gurmukhi","oriya",
    "korean",
    "telugu","tamil","kannada","malayalam","sinhala"
    # ,"eng","binaryv","binaryh","hex",
    # "notosans"
)
for x in scripts:
    x115 = fontforge.open(f"/home/viml/mg/font/sfd/5/115/{x}115.sfd")
    x115.selection.select(("ranges",None),0x901,0x96f)
    x115.copy()
    for x in range(1, 9):
        xmultiplyx80 = x * 0x80
        x115.selection.select(("ranges",None),0x901+xmultiplyx80,0x96f+xmultiplyx80)
        x115.paste()
    x115.save()
    x115.close()

# %%
scripts = (
    "ing",
    "hindi",
    "bangla","guzrati","gurmukhi","oriya",
    "korean",
    "telugu","tamil","kannada","malayalam","sinhala"
    # ,"eng","binaryv","binaryh","hex",
    # "notosans"
)
for x in scripts:
    x115 = fontforge.open(f"/home/viml/mg/font/sfd/5/115/{x}115.sfd")
    x115.generate(f"/home/viml/mg/font/daunlod/fontdrum/{x}115.ttf")
    x115.generate(f"/home/viml/mg/font/daunlod/fontdrum/{x}115.woff2")
    x115.close()

# %%
    # print(f"prefs of l{x}05.sfd:")
    # print(tfont.getPrefs())
    # ff_dict[x] = fontforge.font()
    # ff_dict[x].fontname = tfont.fontname
    # ff_dict[x].familyname = tfont.familyname
    # ff_dict[x].uniqueid = tfont.uniqueid
    # ff_dict[x].xuid = tfont.xuid    
    # ff_dict[x].
    # ff_dict[x].save(f"l{x}05_ff.sfd")
